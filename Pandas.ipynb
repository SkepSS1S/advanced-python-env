# %%
import sys

# %%
# !{sys.executable} -m pip install pandas

# %%
# ex6
import pandas as pd

df = pd.DataFrame({
    "Name": ["Arystan", "Adilet", "Darkhan", "Arsen", "Aizere"],
    "Age": [21, 21, 22, 18, 23],
    "Score": [99, 88, 91, 78, 83]
})

df
# Out:
#       Name  Age  Score
# 0  Arystan   21     99
# 1   Adilet   21     88
# 2  Darkhan   22     91
# 3    Arsen   18     78
# 4   Aizere   23     83

# %%
# ex7
df.head(3)
# Out:
#       Name  Age  Score
# 0  Arystan   21     99
# 1   Adilet   21     88
# 2  Darkhan   22     91

# %%
# ex8
df.describe()
# Out:
#              Age      Score
# count   5.000000   5.000000
# mean   21.000000  87.800000
# std     1.870829   7.981228
# min    18.000000  78.000000
# 25%    21.000000  83.000000
# 50%    21.000000  88.000000
# 75%    22.000000  91.000000
# max    23.000000  99.000000

# %%
# ex9
df["Score"].mean()
# Out:
# np.float64(87.8)

# %%
# ex10
df[df["Age"] > 20]
# Out:
#       Name  Age  Score
# 0  Arystan   21     99
# 1   Adilet   21     88
# 2  Darkhan   22     91
# 4   Aizere   23     83

# %%
# ex11
df[df["Score"] > 80]
# Out:
#       Name  Age  Score
# 0  Arystan   21     99
# 1   Adilet   21     88
# 2  Darkhan   22     91
# 4   Aizere   23     83
